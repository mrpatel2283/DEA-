# %% [markdown]
# ## Pro kabaddi Dataset EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as py
import plotly.tools as tls

# %% [markdown]
# # EDA of Pro- Kabaddi Dataset of 1st CSV File

# %%
df1 = pd.read_csv('C:\\Users\\Darshan\\Desktop\\Datasets\\Pro-Kabaddi\\FixtureResults.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0          Date               HomeTeam               AwayTeam  \
# 0           0  01.10. 01:00        Tamil Thalaivas                U Mumba
# 1           1  01.10. 00:00        Bengal Warriors           Dabang Delhi
# 2           2  30.09. 01:00       Haryana Steelers  Gujarat FortuneGiants
# 3           3  30.09. 00:00          Puneri Paltan           Dabang Delhi
# 4           4  29.09. 01:00  Gujarat FortuneGiants        Tamil Thalaivas
#
#                   Result
# 0                U Mumba
# 1        Bengal Warriors
# 2       Haryana Steelers
# 3           Dabang Delhi
# 4  Gujarat FortuneGiants

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df1
# Out:
#      Unnamed: 0          Date               HomeTeam               AwayTeam  \
# 0             0  01.10. 01:00        Tamil Thalaivas                U Mumba
# 1             1  01.10. 00:00        Bengal Warriors           Dabang Delhi
# 2             2  30.09. 01:00       Haryana Steelers  Gujarat FortuneGiants
# 3             3  30.09. 00:00          Puneri Paltan           Dabang Delhi
# 4             4  29.09. 01:00  Gujarat FortuneGiants        Tamil Thalaivas
# 5             5  29.09. 00:00       Haryana Steelers              UP Yoddha
# 6             6  28.09. 01:00   Jaipur Pink Panthers          Telugu Titans
# 7             7  28.09. 00:00                U Mumba        Bengaluru Bulls
# 8             8  27.09. 00:00          Patna Pirates           Dabang Delhi
# 9             9  26.09. 01:00   Jaipur Pink Panthers          Puneri Paltan
# 10           10  26.09. 00:00          Telugu Titans        Bengal Warriors
# ...

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'HomeTeam', 'AwayTeam', 'Result'], dtype='object')

# %% [raw]
# Observation : It gives us the all the columns from the dataset.

# %%
df1.describe()
# Out:
#        Unnamed: 0
# count  103.000000
# mean    51.000000
# std     29.877528
# min      0.000000
# 25%     25.500000
# 50%     51.000000
# 75%     76.500000
# max    102.000000

# %% [raw]
# Observation : This stats that Count , Minimum Maximum and Standard Deviation of the dataset.

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  103 non-null    int64
#  1   Date        103 non-null    object
#  2   HomeTeam    103 non-null    object
#  3   AwayTeam    103 non-null    object
#  4   Result      103 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.1+ KB

# %% [raw]
# Observation : It gives us the datatype of all the columns.

# %%
df1.shape
# Out:
# (103, 5)

# %% [raw]
# Observation : It gives us the mumber of row and columns from the dataset.

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0    0
# Date          0
# HomeTeam      0
# AwayTeam      0
# Result        0
# dtype: int64

# %% [raw]
# Observation : As shown there is no NULL Value in the dataset.

# %%
df1['HomeTeam'].unique()
# Out:
# array(['Tamil Thalaivas', 'Bengal Warriors', 'Haryana Steelers',
#        'Puneri Paltan', 'Gujarat FortuneGiants', 'Jaipur Pink Panthers',
#        'U Mumba', 'Patna Pirates', 'Telugu Titans', 'Dabang Delhi',
#        'UP Yoddha', 'Bengaluru Bulls'], dtype=object)

# %% [raw]
# Observation : It gives us the all the unique value from the particular column.

# %%
df1['AwayTeam'].unique()
# Out:
# array(['U Mumba', 'Dabang Delhi', 'Gujarat FortuneGiants',
#        'Tamil Thalaivas', 'UP Yoddha', 'Telugu Titans', 'Bengaluru Bulls',
#        'Puneri Paltan', 'Bengal Warriors', 'Haryana Steelers',
#        'Patna Pirates', 'Jaipur Pink Panthers'], dtype=object)

# %%
plt.figure(figsize = (15,10))
sns.countplot('HomeTeam', data = df1)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [raw]
# Observation : This bar graph stats that Begal Warriors played their most number of matche at their home as compare to others.

# %%
plt.figure(figsize = (15,10))
sns.countplot('AwayTeam', data = df1)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [raw]
# Observation : This bar graph states that Bengaluru Bulls and Haryana Steelers played their most number of matches at an Away state as compare to other teams.

# %% [markdown]
# # EDA of Pro- Kabaddi Dataset of 2nd CSV File

# %%
df2 = pd.read_csv('C:\\Users\\Darshan\\Desktop\\Datasets\\Pro-Kabaddi\\Leaguetable.csv')

# %%
df2.head()
# Out:
#    Unnamed: 0  Rank               Team   P   W  L  T  Score Diff.  Pts
# 0           0     1  Dabang Delhi K.C.  20  15  3  2           83   82
# 1           1     2    Bengal Warriors  20  13  4  3           95   78
# 2           2     3   Haryana Steelers  19  12  6  1           24   65
# 3           3     4            U Mumba  19  10  8  1           37   59
# 4           4     5    Bengaluru Bulls  19  10  8  1           12   58

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   12 non-null     int64
#  1   Rank         12 non-null     int64
#  2   Team         12 non-null     object
#  3   P            12 non-null     int64
#  4   W            12 non-null     int64
#  5   L            12 non-null     int64
#  6   T            12 non-null     int64
#  7   Score Diff.  12 non-null     int64
#  8   Pts          12 non-null     int64
# dtypes: int64(8), object(1)
# memory usage: 992.0+ bytes

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df2
# Out:
#     Unnamed: 0  Rank                   Team   P   W   L  T  Score Diff.  Pts
# 0            0     1      Dabang Delhi K.C.  20  15   3  2           83   82
# 1            1     2        Bengal Warriors  20  13   4  3           95   78
# 2            2     3       Haryana Steelers  19  12   6  1           24   65
# 3            3     4                U Mumba  19  10   8  1           37   59
# 4            4     5        Bengaluru Bulls  19  10   8  1           12   58
# 5            5     6            U.P. Yoddha  18  10   6  2          -19   58
# 6            6     7   Jaipur Pink Panthers  20   8  10  2          -18   52
# 7            7     8  Gujarat Fortunegiants  20   6  12  2           14   45
# 8            8     9          Puneri Paltan  20   6  11  3          -71   42
# 9            9    10          Patna Pirates  19   6  12  1           -1   40
# 10          10    11          Telugu Titans  18   5  10  3          -39   39
# ...

# %%
df2.shape
# Out:
# (12, 9)

# %%
df2.describe()
# Out:
#        Unnamed: 0       Rank          P          W          L          T  \
# count   12.000000  12.000000  12.000000  12.000000  12.000000  12.000000
# mean     5.500000   6.500000  19.333333   8.666667   8.666667   2.000000
# std      3.605551   3.605551   0.778499   3.601347   3.420083   0.852803
# min      0.000000   1.000000  18.000000   3.000000   3.000000   1.000000
# 25%      2.750000   3.750000  19.000000   6.000000   6.000000   1.000000
# 50%      5.500000   6.500000  19.500000   9.000000   9.000000   2.000000
# 75%      8.250000   9.250000  20.000000  10.500000  11.250000   3.000000
# max     11.000000  12.000000  20.000000  15.000000  14.000000   3.000000
#
#        Score Diff.        Pts
# count    12.000000  12.000000
# mean      0.000000  54.083333
# std      59.647449  15.715993
# min    -117.000000  31.000000
# 25%     -24.000000  41.500000
# 50%       5.500000  55.000000
# 75%      27.250000  60.500000
# max      95.000000  82.000000

# %%
sns.countplot(df2['Score Diff.'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Score Diff.', ylabel='count'>

# %%
sns.countplot(df2['T'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='T', ylabel='count'>

# %% [raw]
# Observation : This graph shows that from the dataset matches are tied maximum of 3 teams of 4 different teams.

# %%
sns.barplot(x = 'W',y='L',data = df2)
# Out:
# <AxesSubplot:xlabel='W', ylabel='L'>

# %%
sns.countplot('Pts',data=df2)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
Observation : This graph stats that only two teams have same amount of points at the end of completion of desired matches.

# %%
plt.figure(figsize=(15,10))
sns.countplot(x='P',hue='L',data=df2)
plt.show()

# %% [raw]
# Observation : This graph shows that Two teams played 19 matches and lost the same amount of matches i.e. 8 and others are 1.

# %%
plt.figure(figsize = (20,15))
sns.countplot(x='P',hue='W',data=df2)
plt.show()

# %% [raw]
# Observation : The graph shows that Two teams played 20 matches and from that only 1 team won more matches as compare to other team.

# %%
plt.figure(figsize=(11,8))
sns.countplot(x='L',hue='P', data=df2)
# Out:
# <AxesSubplot:xlabel='L', ylabel='count'>

# %% [raw]
# Observation :Only two teams who played 19 matches lost their 8 matches.

# %%
plt.figure(figsize=(10,5))
sns.pairplot(df2)

# %% [raw]
# Observation :This pairplot gives one to one relationship with one variable on x-axis and same variable on y- axis for taking correct measurements.

# %% [markdown]
# # EDA of PRo-Kabaddi Daataset of 3rd CSV File

# %%
df3 = pd.read_csv('C:\\Users\\Darshan\\Desktop\\Datasets\\Pro-Kabaddi\\PlayerData.csv')

# %%
df3.head()
# Out:
#    Unnamed: 0             Name Position          Born             Team  \
# 0           0   Maninder Singh   Raider   Jan 1, 1990  Bengal Warriors
# 1           1     K. Prapanjan   Raider  May 29, 1993  Bengal Warriors
# 2           2   Mohammad Taghi   Raider  Oct 21, 1991  Bengal Warriors
# 3           3    Rakesh Narwal   Raider   May 6, 1995  Bengal Warriors
# 4           4  Ravindra Ramesh   Raider  Apr 16, 1996  Bengal Warriors
#
#       Height Nationality   Weight  Match Played  Points  Career Best Points  \
# 0       6 ft       India    76 kg          20.0   205.0                19.0
# 1  6 ft 1 in       India  83.6 kg          18.0   101.0                12.0
# 2          -        Iran        -           3.0     1.0                 1.0
# 3  6 ft 1 in       India    82 kg           2.0     6.0                 3.0
# 4          -       India        -           3.0     2.0                 2.0
#
#    Not Out Percentage  Raids  Successful Raids  Unsuccessful Raids  \
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df3
# Out:
#      Unnamed: 0                       Name                         Position  \
# 0             0             Maninder Singh                           Raider
# 1             1               K. Prapanjan                           Raider
# 2             2             Mohammad Taghi                           Raider
# 3             3              Rakesh Narwal                           Raider
# 4             4            Ravindra Ramesh                           Raider
# 5             5               Sukesh Hegde                           Raider
# 6             6              Naveen Narwal            Defender, right cover
# 7             7                       Amit           Defender, right corner
# 8             8               Baldev Singh           Defender, right corner
# 9             9                Jeeva Kumar   Defender, right and left cover
# 10           10               Viraj Vishnu             Defender, left cover
# ...

# %%
df3.shape
# Out:
# (220, 30)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 30 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    220 non-null    int64
#  1   Name                          220 non-null    object
#  2   Position                      220 non-null    object
#  3   Born                          220 non-null    object
#  4   Team                          220 non-null    object
#  5   Height                        220 non-null    object
#  6   Nationality                   220 non-null    object
#  7   Weight                        220 non-null    object
#  8   Match Played                  220 non-null    float64
#  9   Points                        220 non-null    float64
#  10  Career Best Points            220 non-null    float64
#  11  Not Out Percentage            220 non-null    float64
# ...

# %%
df3.describe()
# Out:
#        Unnamed: 0  Match Played      Points  Career Best Points  \
# count  220.000000    220.000000  220.000000          220.000000
# mean   109.500000      9.563636   30.195455            5.077273
# std     63.652704      7.126422   44.399936            5.138131
# min      0.000000      0.000000    0.000000            0.000000
# 25%     54.750000      2.000000    1.750000            1.000000
# 50%    109.500000      9.000000   11.500000            4.000000
# 75%    164.250000     17.000000   46.000000            7.000000
# max    219.000000     20.000000  258.000000           29.000000
#
#        Not Out Percentage       Raids  Successful Raids  Unsuccessful Raids  \
# count          220.000000  220.000000        220.000000          220.000000
# mean            48.598273   43.740909         15.186364           10.381818
# std             38.827724   81.437772         34.776085           18.944756
# min              0.000000    0.000000          0.000000            0.000000
# ...

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0                      0
# Name                            0
# Position                        0
# Born                            0
# Team                            0
# Height                          0
# Nationality                     0
# Weight                          0
# Match Played                    0
# Points                          0
# Career Best Points              0
# Not Out Percentage              0
# Raids                           0
# Successful Raids                0
# Unsuccessful Raids              0
# Empty Raid                      0
# Successful Raid Percentage      0
# Raid Touch Points               0
# Raid Bonus Points               0
# Total Raid Points               0
# Super Raids                     0
# Super 10s                       0
# Tackles                         0
# Successful Tackles              0
# Unsuccessful Tackles            0
# Successful Tackles Per Match    0
# Tackle Bonus Points             0
# ...

# %%
df3.groupby(['Position','Team'])['Team'].count()
# Out:
# Position                         Team
# All Rounder                      Bengal Warriors          6
#                                  Bengaluru Bulls          2
#                                  Dabang Delhi K.C.        3
#                                  Gujarat Fortunegiants    4
#                                  Haryana Steelers         1
#                                  Jaipur Pink Panthers     6
#                                  Patna Pirates            5
#                                  Puneri Paltan            3
#                                  Tamil Thalaivas          4
#                                  Telugu Titans            2
#                                  U Mumba                  3
#                                  U.P. Yoddha              5
# Defender                         Bengal Warriors          1
#                                  Bengaluru Bulls          3
#                                  Dabang Delhi K.C.        1
# ...

# %% [raw]
# Observation :Using group by we can group players according to their positions.

# %%
df3.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Position', 'Born', 'Team', 'Height',
#        'Nationality', 'Weight', 'Match Played', 'Points', 'Career Best Points',
#        'Not Out Percentage', 'Raids', 'Successful Raids', 'Unsuccessful Raids',
#        'Empty Raid', 'Successful Raid Percentage', 'Raid Touch Points',
#        'Raid Bonus Points', 'Total Raid Points', 'Super Raids', 'Super 10s',
#        'Tackles', 'Successful Tackles', 'Unsuccessful Tackles',
#        'Successful Tackles Per Match', 'Tackle Bonus Points',
#        'Tackle Success Rate', 'Super Tackles', 'High 5s'],
#       dtype='object')

# %%
df3['Team'].unique()
# Out:
# array(['Bengal Warriors', 'Bengaluru Bulls', 'Dabang Delhi K.C.',
#        'Gujarat Fortunegiants', 'Haryana Steelers',
#        'Jaipur Pink Panthers', 'Patna Pirates', 'Puneri Paltan',
#        'Tamil Thalaivas', 'Telugu Titans', 'U Mumba', 'U.P. Yoddha'],
#       dtype=object)

# %% [raw]
# Observation :It gives unique values of the Team Column of the dataset.

# %%
plt.figure(figsize= (11,8))
sns.countplot('Match Played',data=df3)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [raw]
# Observation :It states that oit of 220 players more than 25 players are those who havn't played any matches and approximately 15 players are those who played 20 matches.

# %%
plt.figure(figsize=(10,8))
sns.countplot('Nationality',data=df3)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [raw]
# Observation :It shows that approximately 180 to 190 players having nationality as an India.

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='Nationality',hue='Position',data=df3)
plt.show()

# %% [raw]
# Observation :The graph states that India is the only country who is having players with different and positions.

# %%
sns.boxplot('Super 10s',data=df3)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
x=df3['Team']
y=df3['Points']
plt.figure(figsize = (20,10))
plt.scatter(x,y)
plt.xlabel('Team ',fontsize=10)
plt.ylabel('Points',fontsize=10)
# Out:
# Text(0, 0.5, 'Points')

# %% [raw]
# Observation :From the Scatter plot we can say that Bengaluru Bulls, Dabang Delhi and Patna Pirates have the players whose individual points are lies between 245 to 260

# %%
plt.figure(figsize=(20,10))
sns.countplot('Successful Tackles',data=df3)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [raw]
# Observation :From the graph we can say that Zero successful tackles count are more as compare to other Successful Tackle numbers.

# %% [markdown]
# # # EDA of Pro-Kabaddi Dataset of 4th CSV File

# %%
df4 = pd.read_csv('C:\\Users\\Darshan\\Desktop\\Datasets\\Pro-Kabaddi\\PointsTable.csv')

# %%
df4.head()
# Out:
#    Unnamed: 0          Date               HomeTeam               AwayTeam  \
# 0           0  01.10. 01:00        Tamil Thalaivas                U Mumba
# 1           1  01.10. 00:00        Bengal Warriors           Dabang Delhi
# 2           2  30.09. 01:00       Haryana Steelers  Gujarat FortuneGiants
# 3           3  30.09. 00:00          Puneri Paltan           Dabang Delhi
# 4           4  29.09. 01:00  Gujarat FortuneGiants        Tamil Thalaivas
#
#    Total_Points_HomeTeam  Total_Points_AwayTeam  FirstHalf_Points_HomeTeam  \
# 0                     32                     36                         11
# 1                     42                     33                         25
# 2                     38                     37                         14
# 3                     40                     60                         16
# 4                     50                     21                         20
#
#    FirstHalf_Points_AwayTeam  SecondHalf_Points_HomeTeam  \
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df4
# Out:
#      Unnamed: 0          Date               HomeTeam               AwayTeam  \
# 0             0  01.10. 01:00        Tamil Thalaivas                U Mumba
# 1             1  01.10. 00:00        Bengal Warriors           Dabang Delhi
# 2             2  30.09. 01:00       Haryana Steelers  Gujarat FortuneGiants
# 3             3  30.09. 00:00          Puneri Paltan           Dabang Delhi
# 4             4  29.09. 01:00  Gujarat FortuneGiants        Tamil Thalaivas
# 5             5  29.09. 00:00       Haryana Steelers              UP Yoddha
# 6             6  28.09. 01:00   Jaipur Pink Panthers          Telugu Titans
# 7             7  28.09. 00:00                U Mumba        Bengaluru Bulls
# 8             8  27.09. 00:00          Patna Pirates           Dabang Delhi
# 9             9  26.09. 01:00   Jaipur Pink Panthers          Puneri Paltan
# 10           10  26.09. 00:00          Telugu Titans        Bengal Warriors
# ...

# %%
df4.shape
# Out:
# (103, 10)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  103 non-null    int64
#  1   Date                        103 non-null    object
#  2   HomeTeam                    103 non-null    object
#  3   AwayTeam                    103 non-null    object
#  4   Total_Points_HomeTeam       103 non-null    int64
#  5   Total_Points_AwayTeam       103 non-null    int64
#  6   FirstHalf_Points_HomeTeam   103 non-null    int64
#  7   FirstHalf_Points_AwayTeam   103 non-null    int64
#  8   SecondHalf_Points_HomeTeam  103 non-null    int64
#  9   SecondHalf_Points_AwayTeam  103 non-null    int64
# dtypes: int64(7), object(3)
# memory usage: 8.2+ KB

# %%
df4.describe()
# Out:
#        Unnamed: 0  Total_Points_HomeTeam  Total_Points_AwayTeam  \
# count  103.000000             103.000000             103.000000
# mean    51.000000              32.699029              33.184466
# std     29.877528               7.061127               7.917154
# min      0.000000              19.000000              20.000000
# 25%     25.500000              28.000000              27.000000
# 50%     51.000000              32.000000              33.000000
# 75%     76.500000              38.500000              38.500000
# max    102.000000              50.000000              60.000000
#
#        FirstHalf_Points_HomeTeam  FirstHalf_Points_AwayTeam  \
# count                 103.000000                 103.000000
# mean                   14.844660                  14.844660
# std                     4.304027                   4.096285
# min                     8.000000                   7.000000
# 25%                    11.000000                  12.000000
# ...

# %%
df4.isnull().sum()
# Out:
# Unnamed: 0                    0
# Date                          0
# HomeTeam                      0
# AwayTeam                      0
# Total_Points_HomeTeam         0
# Total_Points_AwayTeam         0
# FirstHalf_Points_HomeTeam     0
# FirstHalf_Points_AwayTeam     0
# SecondHalf_Points_HomeTeam    0
# SecondHalf_Points_AwayTeam    0
# dtype: int64

# %%
x=df4['HomeTeam']
y=df4['AwayTeam']
plt.figure(figsize = (20,15))
plt.scatter(x,y)
plt.xlabel('HomeTeam',fontsize=10)
plt.ylabel('AwayTeam',fontsize=10)
# Out:
# Text(0, 0.5, 'AwayTeam')

# %%
sns.countplot('Total_Points_HomeTeam',data=df4)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [raw]
# Observation :Home Team scroe 50 or more teams against away team is twice while they scores 30 to 35 points approx 15 to 20 times.

# %%
sns.countplot('Total_Points_AwayTeam',data=df4)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [raw]
# Observation :Total Points Away Team Scored 30 Points more than 8 times by playing against Home Team.

# %%
sns.countplot('FirstHalf_Points_HomeTeam',data=df4)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [raw]
# Observation :Home team scores 11 points 16 times in the 1st half by following 15 points 14 times.

# %%
sns.countplot('FirstHalf_Points_AwayTeam',data=df4)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [raw]
# Observation :Away team scores 13 14 points more than 10 times,15 points 10 times 10 16 17 points 9 times.

# %%
sns.countplot('SecondHalf_Points_HomeTeam',data=df4)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [raw]
# Observation :IN the 2nd half of the game home team scores 12 and 19 points 10 times and 21 points 9 times.

# %%
sns.countplot('SecondHalf_Points_AwayTeam',data=df4)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [raw]
# Observation :In the 2nd half away team scores 13,14,18 and 19 points more thasn 8 times as compare to other points.

# %%
df4['SecondHalf_Points_AwayTeam'].plot(kind = 'bar',figsize=(20,15))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,5))
sns.pairplot(df4)

# %% [markdown]
# # EDA of Pro-Kabaddi Dataset of 5th CSV File

# %%
df5 = pd.read_csv('C:\\Users\\Darshan\\Desktop\\Datasets\\Pro-Kabaddi\\TeamData.csv')

# %%
df5.head()
# Out:
#    Unnamed: 0               Team  Games  TOTAL POINTS SCORED  \
# 0           0  Dabang Delhi K.C.     20                  742
# 1           1    Bengal Warriors     20                  718
# 2           2    Bengaluru Bulls     19                  656
# 3           3      Puneri Paltan     20                  652
# 4           4   Haryana Steelers     19                  650
#
#    TOTAL POINTS CONCEDED  AVG POINTS SCORED  SUCCESSFUL RAIDS  RAID POINTS  \
# 0                    659              31.20               361          437
# 1                    623              30.90               340          426
# 2                    644              30.73               309          393
# 3                    723              29.50               290          358
# 4                    626              30.10               290          377
#
#    AVG RAID POINTS  SUCCESSFUL TACKLES  TACKLE POINTS  AVG TACKLE POINTS  \
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df5
# Out:
#     Unnamed: 0                   Team  Games  TOTAL POINTS SCORED  \
# 0            0      Dabang Delhi K.C.     20                  742
# 1            1        Bengal Warriors     20                  718
# 2            2        Bengaluru Bulls     19                  656
# 3            3          Puneri Paltan     20                  652
# 4            4       Haryana Steelers     19                  650
# 5            5          Patna Pirates     19                  640
# 6            6   Jaipur Pink Panthers     20                  626
# 7            7  Gujarat Fortunegiants     20                  605
# 8            8                U Mumba     19                  598
# 9            9        Tamil Thalaivas     20                  578
# 10          10          Telugu Titans     18                  564
# 11          11            U.P. Yoddha     18                  551
#
#     TOTAL POINTS CONCEDED  AVG POINTS SCORED  SUCCESSFUL RAIDS  RAID POINTS  \
# ...

# %%
df5.shape
# Out:
# (12, 17)

# %%
df5.describe()
# Out:
#        Unnamed: 0      Games  TOTAL POINTS SCORED  TOTAL POINTS CONCEDED  \
# count   12.000000  12.000000            12.000000              12.000000
# mean     5.500000  19.333333           631.666667             631.666667
# std      3.605551   0.778499            57.903263              47.549655
# min      0.000000  18.000000           551.000000             561.000000
# 25%      2.750000  19.000000           593.000000             600.000000
# 50%      5.500000  19.500000           633.000000             633.500000
# 75%      8.250000  20.000000           653.000000             647.750000
# max     11.000000  20.000000           742.000000             723.000000
#
#        AVG POINTS SCORED  SUCCESSFUL RAIDS  RAID POINTS  AVG RAID POINTS  \
# count          12.000000         12.000000    12.000000        12.000000
# mean           28.629167        286.333333   358.833333        18.550000
# std             1.956525         37.215181    43.848569         2.028192
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             12 non-null     int64
#  1   Team                   12 non-null     object
#  2   Games                  12 non-null     int64
#  3   TOTAL POINTS SCORED    12 non-null     int64
#  4   TOTAL POINTS CONCEDED  12 non-null     int64
#  5   AVG POINTS SCORED      12 non-null     float64
#  6   SUCCESSFUL RAIDS       12 non-null     int64
#  7   RAID POINTS            12 non-null     int64
#  8   AVG RAID POINTS        12 non-null     float64
#  9   SUCCESSFUL TACKLES     12 non-null     int64
#  10  TACKLE POINTS          12 non-null     int64
#  11  AVG TACKLE POINTS      12 non-null     float64
#  12  SUPER RAID             12 non-null     int64
#  13  SUPER TACKLES          12 non-null     int64
#  14  DO-OR-DIE RAID POINTS  12 non-null     int64
# ...

# %%
df5.isnull().sum()
# Out:
# Unnamed: 0               0
# Team                     0
# Games                    0
# TOTAL POINTS SCORED      0
# TOTAL POINTS CONCEDED    0
# AVG POINTS SCORED        0
# SUCCESSFUL RAIDS         0
# RAID POINTS              0
# AVG RAID POINTS          0
# SUCCESSFUL TACKLES       0
# TACKLE POINTS            0
# AVG TACKLE POINTS        0
# SUPER RAID               0
# SUPER TACKLES            0
# DO-OR-DIE RAID POINTS    0
# ALL-OUTS INFLICTED       0
# ALL-OUTS CONCEDED        0
# dtype: int64

# %%
df5.groupby(['ALL-OUTS INFLICTED','ALL-OUTS CONCEDED'])['ALL-OUTS CONCEDED'].count()
# Out:
# ALL-OUTS INFLICTED  ALL-OUTS CONCEDED
# 13                  22                   1
# 14                  30                   1
# 18                  33                   1
# 19                  23                   1
# 21                  22                   2
#                     24                   1
# 26                  21                   1
# 27                  21                   1
# 28                  23                   1
# 34                  17                   1
#                     18                   1
# Name: ALL-OUTS CONCEDED, dtype: int64

# %%
df5['Games'].unique()
# Out:
# array([20, 19, 18], dtype=int64)

# %%
df5['Games'].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
Observation :out of 12 count 6 times 20 games has been played , 4 times 19 games has been played and else are remaining.

# %%
sns.boxplot('SUCCESSFUL TACKLES',data=df5)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [raw]
# Observation :From the graph we can say that Successful Tackles point are as mimimum as 170 and maximum are between 180 to 190 and tackle points morethan 200 is an outlier for the particular column count

# %%
sns.barplot('TACKLE POINTS',data=df5)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [raw]
# Observation :from the graph we can conclude that Tackle Points are scored in the league is in range of 185 to 200.

# %%
x=df5['TOTAL POINTS SCORED']
y=df5['TOTAL POINTS CONCEDED']
plt.scatter(x,y)
plt.xlabel('TOTAL POINTS SCORED',fontsize=10)
plt.ylabel('TOTAL POINTS CONCEDED',fontsize=10)
# Out:
# Text(0, 0.5, 'TOTAL POINTS CONCEDED')

# %%
Observation :From the graph we can say that Team who scored 730 to 735 points has only conceded 650 to 660 points.
where team who scored 550 points conceded the points more than they scored which is 570.

# %%
x=df5['ALL-OUTS INFLICTED']
y=df5['ALL-OUTS CONCEDED']
plt.scatter(x,y)
plt.xlabel('ALL-OUTS INFLICTED',fontsize=10)
plt.ylabel('ALL-OUTS CONCEDED',fontsize=10)
# Out:
# Text(0, 0.5, 'ALL-OUTS CONCEDED')

# %% [raw]
# Observation :From the plot we can say that team who inflicted by ALLOUT 33 to 35 points has only conceded 16 to 18 points.
# And who scored 18 to 19 points conceded more than 32 to 35 points.

# %%
sns.countplot('SUCCESSFUL TACKLES',hue = 'Team',data=df5)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [raw]
# Observation :From the graph we can say that 168 Tackels done by Bengaluru Bulls ,Patna Pirates and Haryana Steelers.
# Most Sucessful tackles which is 207 is done by the team Puneri Paltan.

# %%
plt.figure(figsize = (25,10))
sns.countplot('SUCCESSFUL RAIDS',hue = 'Team',data=df5)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [raw]
# Observation :From the graph we can say that 361 number of successful raids are performed by Dabang Delhi.
# and 2nd most raid points scored by Bengal Warriors.

# %% [markdown]
# # EDA of Pro-Kabaddi Dataset of 6th CSV File

# %%
df6 = pd.read_csv('C:\\Users\\Darshan\\Desktop\\Datasets\\Pro-Kabaddi\\Upcomingfixtures.csv')

# %%
df6.head()
# Out:
#    Unnamed: 0          date              HomeTeam         AwayTeam
# 0           0  03.10. 00:00               U Mumba    Patna Pirates
# 1           1  03.10. 01:00      Haryana Steelers  Bengaluru Bulls
# 2           2  04.10. 00:00         Telugu Titans    Puneri Paltan
# 3           3  05.10. 00:00  Jaipur Pink Panthers  Bengaluru Bulls
# 4           4  05.10. 01:00      Haryana Steelers    Telugu Titans

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df6
# Out:
#     Unnamed: 0          date               HomeTeam               AwayTeam
# 0            0  03.10. 00:00                U Mumba          Patna Pirates
# 1            1  03.10. 01:00       Haryana Steelers        Bengaluru Bulls
# 2            2  04.10. 00:00          Telugu Titans          Puneri Paltan
# 3            3  05.10. 00:00   Jaipur Pink Panthers        Bengaluru Bulls
# 4            4  05.10. 01:00       Haryana Steelers          Telugu Titans
# 5            5  06.10. 00:00              UP Yoddha           Dabang Delhi
# 6            6  06.10. 01:00  Gujarat FortuneGiants          Patna Pirates
# 7            7  07.10. 00:00        Bengal Warriors          Patna Pirates
# 8            8  07.10. 01:00              UP Yoddha          Puneri Paltan
# 9            9  08.10. 00:00          Telugu Titans  Gujarat FortuneGiants
# 10          10  08.10. 01:00        Tamil Thalaivas   Jaipur Pink Panthers
# ...

# %%
df6.shape
# Out:
# (16, 4)

# %%
df6['HomeTeam'].unique()
# Out:
# array(['U Mumba', 'Haryana Steelers', 'Telugu Titans',
#        'Jaipur Pink Panthers', 'UP Yoddha', 'Gujarat FortuneGiants',
#        'Bengal Warriors', 'Tamil Thalaivas', 'Dabang Delhi'], dtype=object)

# %%
df6['AwayTeam'].unique()
# Out:
# array(['Patna Pirates', 'Bengaluru Bulls', 'Puneri Paltan',
#        'Telugu Titans', 'Dabang Delhi', 'Gujarat FortuneGiants',
#        'Jaipur Pink Panthers', 'Tamil Thalaivas', 'Haryana Steelers',
#        'U Mumba'], dtype=object)

# %%
plt.figure(figsize = (10,5))
sns.countplot(df6['HomeTeam'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [raw]
# Observation :From the above graph we can say that UP Yoddha team has organized matches at their home 4 times as compare to others.

# %%
plt.figure(figsize = (12,9))
sns.countplot(df6['AwayTeam'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %% [raw]
# Observation :From the above graph we can conclude that 6 Away teams have organized matches only 1 time.

# %%
plt.figure(figsize = (15,10))
sns.countplot(x = 'HomeTeam', hue = 'AwayTeam', data = df6)
plt.show()
